# %%
students = [
    "Arpitha", "Anu", "Rahul", "Kiran", "Priya"
]

while True:
    print("\n===== TNS STUDENT MANAGEMENT =====")
    print("1. View Students")
    print("2. Add Student")
    print("3. Remove Student")
    print("4. Total Students")
    print("5. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print("\nStudents in Batch:")
        for student in students:
            print(student)

    elif choice == 2:
        name = input("Enter new student name: ")
        students.append(name)
        print(name, "added successfully!")

    elif choice == 3:
        name = input("Enter student name to remove: ")
        if name in students:
            students.remove(name)
            print(name, "removed successfully!")
        else:
            print("Student not found!")

    elif choice == 4:
        print("Total Students:", len(students))

    elif choice == 5:
        print("Thank You!")
        break

    else:
        print("Invalid Choice!")
# Out:
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 1
#
# Students in Batch:
# Arpitha
# Anu
# Rahul
# Kiran
# Priya
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 2
# Enter new student name: Bharath
# Bharath added successfully!
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 1
#
# Students in Batch:
# Arpitha
# Anu
# Rahul
# Kiran
# Priya
# Bharath
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 3
# Enter student name to remove: priya
# Student not found!
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 1
#
# Students in Batch:
# Arpitha
# Anu
# Rahul
# Kiran
# Priya
# Bharath
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
# Enter your choice: 4
# Total Students: 6
#
# ===== TNS STUDENT MANAGEMENT =====
# 1. View Students
# 2. Add Student
# 3. Remove Student
# 4. Total Students
# 5. Exit
