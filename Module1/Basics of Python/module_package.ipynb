# %%
# %%writefile mymodule.py

def add(a,b):
    return a+b

def square(n):
    return n*n

def greet(name):
    return "Hello " + name
# Out:
# Writing mymodule.py

# %%
from mymodule import add
from mymodule import square
from mymodule import greet

print(add(10,20))
print(square(5))
print(greet("Arpitha"))
# Out:
# 30
# 25
# Hello Arpitha
